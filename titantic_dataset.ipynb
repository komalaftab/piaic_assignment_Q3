# %% [markdown]
# **Objective**

# %% [markdown]
# **Use Deep learning to create a model that predicts which passengers survived the Titanic shipwreck.**

# %% [markdown]
# *  Load data
# *  Data exploratory
# *   Check missing value
# *  Feature analysis
# *   Handle missing values
# *  Joining test and train data
# *    One hot coding
# * Splitting data
# *  Traning model using neural network
# * Predication
# *  Saving submission file in csv format

# %% [markdown]
# **load data using this link**
# https://www.kaggle.com/competitions/titanic/data

# %% [markdown]
# *how to submit prdication*

# %% [markdown]
# **step 1**
# click on this link ;; https://www.kaggle.com/competitions/titanic/submissions

# %% [markdown]
# ![k1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![k2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ***share your predictions with me whatsapp group***

# %% [markdown]
# ![k3.JPG](data:image/jpeg;base64,...)
